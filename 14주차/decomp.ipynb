# %%
import os
import pandas as pd
import numpy as np
from tqdm import tnrange

# %%
path
# Out:
# '/Users/Wook-Young/Desktop/RA/code/RA_code/eyetracking_intention/s0'

# %%
path = '/Users/Wook-Young/Desktop/RA/code/RA_code/eyetracking_intention/s0'
path1 = '/Users/Wook-Young/Desktop/RA/code/RA_code/eyetracking_intention/s0' + '/f_s0'
path2 = '/Users/Wook-Young/Desktop/RA/code/RA_code/eyetracking_intention/s0' + '/f_s0'

# %%
for i in tnrange(2, 9):
    os.chdir(path + str(i+1) + '/f_s0' + str(i+1))
    for j in range(4):
        os.chdir(path + str(i+1) + '/f_s0' + str(i+1))
        video = pd.read_csv('f_s0'+str(i+1)+'_r0'+str(j+1)+'.txt', header = None)
        found = np.where(video[video==18].values[0] == 18)[0]
        if not found.size:
            continue
        times = pd.read_csv('f_s0'+str(i+1)+'_r0'+str(j+1)+'_tsk'+str(found[0]+1)+'.txt', header = None)
        timess = pd.read_csv('f_s0'+str(i+1)+'_r0'+str(j+1)+'_dur'+str(found[0]+1)+'.txt', header = None)
        timesss = [float(times.values[0][0]), float(times.values[0][0])+float(timess.values[0][0])]
        os.chdir(path + str(i+1) + '/f_s0' + str(i+1) + 's0' + str(i+1))
        data = pd.read_csv('s0'+str(i+1)+str(j+1)+'.txt')
        data = data.loc[(data.ATT >= timesss[0]) & (data.ATT <= timesss[1])]
        os.chdir(path + str(i+1))
        data.to_csv('s0'+str(i+1)+str(j+1)+'_18'+'.txt')

# %%
times.values[0]
# Out:
# array([954.27])

# %%
for i in tnrange(2):
    os.chdir(path + str(i+1) + '/f_s0' + str(i+1))
    for j in range(4):
        os.chdir(path + str(i+1) + '/f_s0' + str(i+1))
        video = pd.read_csv('f_s0'+str(i+1)+'_r0'+str(j+1)+'.txt', header = None)
        found = np.where(video[video==18].values[0] == 18)[0]
        if not found.size:
            continue
        times = pd.read_csv('f_s0'+str(i+1)+'_r0'+str(j+1)+'_tsk'+'.txt', header = None)
        times = times[found[0]*2:found[0]*2+2].values.tolist()
        timess = []
        for k in range(2):
            timess.append(float(times[k][0].split('\t')[1]))
        os.chdir(path + str(i+1) + '/f_s0' + str(i+1) + 's0' + str(i+1))
        data = pd.read_csv('s0'+str(i+1)+str(j+1)+'.txt')
        data = data.loc[(data.ATT >= timess[0]) & (data.ATT <= timess[1])]
        os.chdir(path + str(i+1))
        data.to_csv('s0'+str(i+1)+str(j+1)+'_18'+'.txt')

# %%
i=1
os.chdir(path + str(i))
data = pd.read_csv('s013_18.txt')
data['APWH'] = data.APW * data.APH
data['BPWH'] = data.BPW * data.BPH
data = data[['APWH','BPWH']]

# %%
data.shape
# Out:
# (9942, 2)

# %%
i=3
os.chdir(path + str(i))
data2 = pd.read_csv('s031_18.txt')
data2['APWH'] = data2.APW * data2.APH
data2['BPWH'] = data2.BPW * data2.BPH
data2 = data2[['APWH','BPWH']]

# %%
data2.shape
# Out:
# (9942, 2)

# %%
i=4
os.chdir(path + str(i))
data3 = pd.read_csv('s044_18.txt')
data3['APWH'] = data3.APW * data3.APH
data3['BPWH'] = data3.BPW * data3.BPH
data3 = data3[['APWH','BPWH']]

# %%
data3.shape
# Out:
# (9951, 2)

# %%
i=5
os.chdir(path + str(i))
data4 = pd.read_csv('s052_18.txt')
data4['APWH'] = data4.APW * data4.APH
data4['BPWH'] = data4.BPW * data4.BPH
data4 = data4[['APWH','BPWH']]

# %%
data4.shape
# Out:
# (9941, 2)

# %%
#import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly
from tqdm import tnrange
plotly.tools.set_credentials_file(username='serereuk', api_key='KrI0ugSnjcltrwQkSmbO')
# %matplotlib inline
#%matplotlib widget

# %%
sns.tsplot(data.APWH)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning:
#
# The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
sns.tsplot(data2.APWH)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning:
#
# The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.

# %%
temp = pd.DataFrame({'a': data.APWH, 'b': data2.APWH})

# %%
a,b,c= np.linalg.svd(temp.values, full_matrices=False)

# %%
a.shape, b.shape, c.shape
# Out:
# ((9942, 2), (2,), (2, 2))

# %%
sns.tsplot(a[:,0] * b[0] * c[0,0])
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning:
#
# The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
sns.tsplot(a[:,1] * b[1] * c[1,1])
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning:
#
# The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
